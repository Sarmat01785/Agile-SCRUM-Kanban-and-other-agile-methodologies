# %% [markdown]
# # Урок 10. Семинар. Kanban

# %% [markdown]
# ### Задача:
#
# Проанализируйте свой процесс обучения в ИТ-сфере и продвижение по карьере в этом направлении. Выделите задачи, которые стоят перед Вами на месяц/квартал/год (на Ваше усмотрение). Ранжируйте поставленные задачи по классам обслуживания – выберите цвета для Kanban-карточек. Определите WiP для управления потоком незавершённых задач. Отразите определённые Вами задачи на личной Kanban-доске.

# %% [markdown]
# Шаг 1: Выделение задач
#
# Ключевые задачи на выбранный период (месяц, квартал, год):
#
# - Изучение языка программирования Python.
# - Завершение курса по управлению проектами.
# - Создание портфолио для поиска работы в ИТ.
# - Проведение трех собеседований в ИТ-компаниях.
# - Получение сертификата по Agile-методологиям.

# %% [markdown]
# Шаг 2: Ранжирование задач по классам обслуживания
#
# Классы обслуживания могут быть определены по приоритету или срокам выполнения. Цвета для Kanban-карточек, чтобы отразить классы обслуживания:
#
# - Срочные/высокий приоритет (красный)
# - Стандартные/средний приоритет (желтый)
# - Низкий приоритет/можно отложить (зеленый)

# %% [markdown]
# Шаг 3: Определение WiP (Work in Progress) лимитов
#
# WiP лимиты помогут мне контролировать количество одновременно выполняемых задач:
#
# - Максимум 2 учебных задачи одновременно.
# - Одна задача по поиску работы или подготовке к собеседованиям.

# %% [markdown]
# Шаг 4: Создание Kanban-доски
#
# Kanban-доска может быть организована следующим образом:

# %% [markdown]
# | To Do (Планируется) | In Progress (В работе) | Done (Выполнено) |
# |---------------------|------------------------|------------------|
# | Курс по Python (🟡)      | Сертификация Agile (🔴)| Портфолио (🟢)    |
# | Собеседование 1 (🔴) |                        |                  |
# | Собеседование 2 (🔴) |                        |                  |
# | Курс по управлению (🟡) |                    |                  |

# %% [markdown]
# P.S.
#
# - Каждая задача представлена карточкой с указанным цветом класса обслуживания.
#
# - Задачи перемещаются с левой стороны на правую по мере выполнения.
#
# - Нужно соблюдать WiP лимиты, не перегружая колонку "В работе".
